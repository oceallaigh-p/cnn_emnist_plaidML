# %%
# Add GPU support through PlaidML
import os
os.environ["KERAS_BACKEND"] = "plaidml.keras.backend"

import keras
# Out:
# Using plaidml.keras.backend backend.

# %%
# Import modules
from keras import layers
from keras import models
from keras import utils
from keras import callbacks

from keras.models import load_model

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics

# %%
## Constants

# Image Dimensions (pixels)
HEIGHT = 28
WIDTH = 28

# Train test split
TEST_SIZE = 0.15   # 85 / 15 split

# Random seed
SEED = 4242

# Batch size and number of training epochs
BATCH_SIZE = 256
EPOCHS = 5000

# Early stop parameters
PATIENCE = 25                          # Number of epochs without improvement
MIN_DELTA = 0.0001                     # Minimum change to be considered improvement
MONITOR = 'val_loss'                   # Variable being monitored
MODE = 'min'                           # Mode for monitor (minimize validation loss)
FILE_PATH = 'best_model_cnn_emnist.h5' # Path to saved model

# %%
# Fix numpy random seed
np.random.seed(SEED)

# %%
# Load data
train = pd.read_csv("/Users/patrickoceallaigh/Data/EMNIST/kaggle_csv/emnist-balanced-train.csv",delimiter = ',')
test = pd.read_csv("/Users/patrickoceallaigh/Data/EMNIST/kaggle_csv/emnist-balanced-test.csv", delimiter = ',')
mapp = pd.read_csv("/Users/patrickoceallaigh/Data/EMNIST/kaggle_csv/emnist-balanced-mapping.txt", delimiter = ' ',
                   index_col = 0, header = None, squeeze = True)

print("Train: %s, Test: %s, Map: %s" %(train.shape, test.shape, mapp.shape))
# Out:
# Train: (112799, 785), Test: (18799, 785), Map: (47,)

# %%
# Split x and y
train_x = train.iloc[:,1:]
train_y = train.iloc[:,0]
del train

test_x = test.iloc[:,1:]
test_y = test.iloc[:,0]
del test

print(train_x.shape,train_y.shape,test_x.shape,test_y.shape)
# Out:
# (112799, 784) (112799,) (18799, 784) (18799,)

# %%
# Define function to flip and rotate image
def rotate(image):
    image = image.reshape([HEIGHT, WIDTH])
    image = np.fliplr(image)
    image = np.rot90(image)
    return image

# %%
# Flip and rotate image
train_x = np.asarray(train_x)
train_x = np.apply_along_axis(rotate, 1, train_x)
print ("train_x:",train_x.shape)

test_x = np.asarray(test_x)
test_x = np.apply_along_axis(rotate, 1, test_x)
print ("test_x:",test_x.shape)
# Out:
# train_x: (112799, 28, 28)
# test_x: (18799, 28, 28)

# %%
# Normalise
train_x = train_x.astype('float32')
train_x /= 255
test_x = test_x.astype('float32')
test_x /= 255

# %%
# Plot images
for i in range(100, 109):
    plt.subplot(330 + (i+1))
    plt.imshow(train_x[i], cmap = plt.get_cmap('gray'))
    plt.title(chr(mapp[train_y[i]]))

# %%
# Number of classes
num_classes = train_y.nunique()
print ("Number of Classes:", num_classes)
# Out:
# Number of Classes: 47

# %%
# One hot encoding
train_y = utils.np_utils.to_categorical(train_y, num_classes)
test_y = utils.np_utils.to_categorical(test_y, num_classes)
print("train_y: ", train_y.shape)
print("test_y: ", test_y.shape)
# Out:
# train_y:  (112799, 47)
# test_y:  (18799, 47)

# %%
# Reshape image for CNN
train_x = train_x.reshape(-1, HEIGHT, WIDTH, 1)
test_x = test_x.reshape(-1, HEIGHT, WIDTH, 1)

# %%
# Partition to train and val
train_x, val_x, train_y, val_y = train_test_split(train_x, train_y, test_size = TEST_SIZE, random_state = SEED)

# %%
# Build model
model = models.Sequential()

model.add(layers.Conv2D(filters = 32,
                        kernel_size = (3,3),
                        padding = 'same',
                        activation = 'relu',
                        input_shape = (HEIGHT, WIDTH,1)))
model.add(layers.MaxPooling2D(pool_size = (2,2)))
model.add(layers.Conv2D(filters = 64,
                        kernel_size = (3,3),
                        padding = 'same',
                        activation = 'relu'))
model.add(layers.MaxPooling2D(pool_size = (2,2)))
model.add(layers.Conv2D(filters = 64,
                        kernel_size = (3,3),
                        padding = 'same',
                        activation = 'relu'))
model.add(layers.MaxPooling2D(pool_size=(2,2)))
model.add(layers.Flatten())
model.add(layers.Dropout(.5))
model.add(layers.Dense(units = 64,
                       activation = 'relu'))
model.add(layers.Dense(units = num_classes,
                       activation = 'softmax'))

model.summary()
# Out:
# INFO:plaidml:Opening device "metal_amd_radeon_pro_vega_56.0"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 28, 28, 32)        320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 64)          36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 576)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                36928
# _________________________________________________________________
# dense_2 (Dense)              (None, 47)                3055
# =================================================================
# Total params: 95,727
# Trainable params: 95,727
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile model
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
# Set callback functions to stop training early and save the best model so far
keras_callbacks   = [
    callbacks.EarlyStopping(monitor = MONITOR, patience = PATIENCE, mode = MODE, min_delta = MIN_DELTA, verbose = 1),
    callbacks.ModelCheckpoint(filepath = FILE_PATH, monitor = MONITOR, save_best_only = True, mode = MODE, verbose = 1)
]

# %%
# Fit model
model_history = model.fit(train_x, train_y,
                    epochs = EPOCHS,
                    batch_size = BATCH_SIZE,
                    verbose = 1,
                    validation_data=(val_x, val_y), 
                    callbacks = keras_callbacks)
# Out:
# Train on 95879 samples, validate on 16920 samples
# Epoch 1/5000
# 95879/95879 [==============================] - 19s 196us/step - loss: 1.4674 - acc: 0.5740 - val_loss: 0.5465 - val_acc: 0.8195
#
# Epoch 00001: val_loss improved from inf to 0.54651, saving model to best_model_cnn_emnist.h5
# Epoch 2/5000
# 95879/95879 [==============================] - 17s 181us/step - loss: 0.6355 - acc: 0.7905 - val_loss: 0.4457 - val_acc: 0.8463
#
# Epoch 00002: val_loss improved from 0.54651 to 0.44568, saving model to best_model_cnn_emnist.h5
# Epoch 3/5000
# 95879/95879 [==============================] - 17s 181us/step - loss: 0.5357 - acc: 0.8197 - val_loss: 0.4092 - val_acc: 0.8594
#
# Epoch 00003: val_loss improved from 0.44568 to 0.40924, saving model to best_model_cnn_emnist.h5
# Epoch 4/5000
# 95879/95879 [==============================] - 17s 182us/step - loss: 0.4902 - acc: 0.8339 - val_loss: 0.3778 - val_acc: 0.8684
#
# Epoch 00004: val_loss improved from 0.40924 to 0.37776, saving model to best_model_cnn_emnist.h5
# Epoch 5/5000
# 95879/95879 [==============================] - 18s 183us/step - loss: 0.4603 - acc: 0.8424 - val_loss: 0.3703 - val_acc: 0.8703
#
# Epoch 00005: val_loss improved from 0.37776 to 0.37032, saving model to best_model_cnn_emnist.h5
# Epoch 6/5000
# 95879/95879 [==============================] - 17s 181us/step - loss: 0.4391 - acc: 0.8486 - val_loss: 0.3582 - val_acc: 0.8746
#
# Epoch 00006: val_loss improved from 0.37032 to 0.35825, saving model to best_model_cnn_emnist.h5
# Epoch 7/5000
# 95879/95879 [==============================] - 17s 182us/step - loss: 0.4239 - acc: 0.8536 - val_loss: 0.3602 - val_acc: 0.8719
#
# Epoch 00007: val_loss did not improve from 0.35825
# Epoch 8/5000
# 95879/95879 [==============================] - 17s 181us/step - loss: 0.4112 - acc: 0.8564 - val_loss: 0.3416 - val_acc: 0.8770
#
# Epoch 00008: val_loss improved from 0.35825 to 0.34160, saving model to best_model_cnn_emnist.h5
# Epoch 9/5000
# 95879/95879 [==============================] - 17s 180us/step - loss: 0.3997 - acc: 0.8594 - val_loss: 0.3465 - val_acc: 0.8748
#
# Epoch 00009: val_loss did not improve from 0.34160
# Epoch 10/5000
# 95879/95879 [==============================] - 17s 180us/step - loss: 0.3940 - acc: 0.8625 - val_loss: 0.3308 - val_acc: 0.8796
#
# Epoch 00010: val_loss improved from 0.34160 to 0.33081, saving model to best_model_cnn_emnist.h5
# Epoch 11/5000
# 95879/95879 [==============================] - 18s 185us/step - loss: 0.3815 - acc: 0.8643 - val_loss: 0.3265 - val_acc: 0.8813
#
# Epoch 00011: val_loss improved from 0.33081 to 0.32650, saving model to best_model_cnn_emnist.h5
# Epoch 12/5000
# 95879/95879 [==============================] - 17s 181us/step - loss: 0.3709 - acc: 0.8680 - val_loss: 0.3287 - val_acc: 0.8811
#
# Epoch 00012: val_loss did not improve from 0.32650
# Epoch 13/5000
# 95879/95879 [==============================] - 17s 181us/step - loss: 0.3702 - acc: 0.8687 - val_loss: 0.3239 - val_acc: 0.8817
#
# Epoch 00013: val_loss improved from 0.32650 to 0.32387, saving model to best_model_cnn_emnist.h5
# Epoch 14/5000
# 95879/95879 [==============================] - 19s 193us/step - loss: 0.3618 - acc: 0.8703 - val_loss: 0.3206 - val_acc: 0.8845
#
# Epoch 00014: val_loss improved from 0.32387 to 0.32064, saving model to best_model_cnn_emnist.h5
# Epoch 15/5000
# 95879/95879 [==============================] - 18s 189us/step - loss: 0.3567 - acc: 0.8727 - val_loss: 0.3193 - val_acc: 0.8856
#
# Epoch 00015: val_loss improved from 0.32064 to 0.31931, saving model to best_model_cnn_emnist.h5
# Epoch 16/5000
# 95879/95879 [==============================] - 19s 194us/step - loss: 0.3499 - acc: 0.8728 - val_loss: 0.3119 - val_acc: 0.8878
#
# Epoch 00016: val_loss improved from 0.31931 to 0.31192, saving model to best_model_cnn_emnist.h5
# Epoch 17/5000
# 95879/95879 [==============================] - 19s 197us/step - loss: 0.3467 - acc: 0.8744 - val_loss: 0.3115 - val_acc: 0.8887
#
# Epoch 00017: val_loss improved from 0.31192 to 0.31151, saving model to best_model_cnn_emnist.h5
# Epoch 18/5000
# 95879/95879 [==============================] - 19s 198us/step - loss: 0.3407 - acc: 0.8761 - val_loss: 0.3129 - val_acc: 0.8863
#
# Epoch 00018: val_loss did not improve from 0.31151
# Epoch 19/5000
# 95879/95879 [==============================] - 18s 193us/step - loss: 0.3377 - acc: 0.8777 - val_loss: 0.3076 - val_acc: 0.8864
#
# Epoch 00019: val_loss improved from 0.31151 to 0.30764, saving model to best_model_cnn_emnist.h5
# Epoch 20/5000
# 95879/95879 [==============================] - 19s 194us/step - loss: 0.3324 - acc: 0.8786 - val_loss: 0.3090 - val_acc: 0.8879
#
# Epoch 00020: val_loss did not improve from 0.30764
# Epoch 21/5000
#  - ETA: 8s - loss: 0.3307 - acc: 0.8794
#
# Epoch 00021: val_loss did not improve from 0.30764
# Epoch 22/5000
# 95879/95879 [==============================] - 19s 193us/step - loss: 0.3250 - acc: 0.8804 - val_loss: 0.3074 - val_acc: 0.8900
#
# Epoch 00022: val_loss improved from 0.30764 to 0.30738, saving model to best_model_cnn_emnist.h5
# Epoch 23/5000
# 95879/95879 [==============================] - 18s 191us/step - loss: 0.3234 - acc: 0.8817 - val_loss: 0.3114 - val_acc: 0.8878
#
# Epoch 00023: val_loss did not improve from 0.30738
# Epoch 24/5000
# 95879/95879 [==============================] - 18s 188us/step - loss: 0.3191 - acc: 0.8826 - val_loss: 0.3074 - val_acc: 0.8889
#
# Epoch 00024: val_loss did not improve from 0.30738
# Epoch 25/5000
# 95879/95879 [==============================] - 18s 189us/step - loss: 0.3178 - acc: 0.8813 - val_loss: 0.3049 - val_acc: 0.8900
#
# Epoch 00025: val_loss improved from 0.30738 to 0.30492, saving model to best_model_cnn_emnist.h5
# Epoch 26/5000
# 95879/95879 [==============================] - 18s 188us/step - loss: 0.3141 - acc: 0.8846 - val_loss: 0.3040 - val_acc: 0.8892
#
# Epoch 00026: val_loss improved from 0.30492 to 0.30396, saving model to best_model_cnn_emnist.h5
# Epoch 27/5000
# 95879/95879 [==============================] - 17s 182us/step - loss: 0.3081 - acc: 0.8849 - val_loss: 0.3069 - val_acc: 0.8903
#
# Epoch 00027: val_loss did not improve from 0.30396
# Epoch 28/5000
# 95879/95879 [==============================] - 17s 181us/step - loss: 0.3077 - acc: 0.8863 - val_loss: 0.3010 - val_acc: 0.8892
#
# Epoch 00028: val_loss improved from 0.30396 to 0.30097, saving model to best_model_cnn_emnist.h5
# Epoch 29/5000
# 95879/95879 [==============================] - 17s 182us/step - loss: 0.3031 - acc: 0.8861 - val_loss: 0.3015 - val_acc: 0.8927
#
# Epoch 00029: val_loss did not improve from 0.30097
# Epoch 30/5000
# 95879/95879 [==============================] - 18s 186us/step - loss: 0.3027 - acc: 0.8881 - val_loss: 0.3051 - val_acc: 0.8936
#
# Epoch 00030: val_loss did not improve from 0.30097
# Epoch 31/5000
# 95879/95879 [==============================] - 18s 186us/step - loss: 0.2999 - acc: 0.8885 - val_loss: 0.3025 - val_acc: 0.8928
#
# Epoch 00031: val_loss did not improve from 0.30097
# Epoch 32/5000
# 95879/95879 [==============================] - 18s 187us/step - loss: 0.2962 - acc: 0.8885 - val_loss: 0.3016 - val_acc: 0.8879
#
# Epoch 00032: val_loss did not improve from 0.30097
# Epoch 33/5000
# 95879/95879 [==============================] - 18s 186us/step - loss: 0.2969 - acc: 0.8889 - val_loss: 0.3009 - val_acc: 0.8905
#
# Epoch 00033: val_loss improved from 0.30097 to 0.30085, saving model to best_model_cnn_emnist.h5
# Epoch 34/5000
# 95879/95879 [==============================] - 18s 185us/step - loss: 0.2964 - acc: 0.8888 - val_loss: 0.3038 - val_acc: 0.8908
#
# Epoch 00034: val_loss did not improve from 0.30085
# Epoch 35/5000
# 95879/95879 [==============================] - 18s 187us/step - loss: 0.2932 - acc: 0.8899 - val_loss: 0.2997 - val_acc: 0.8924
#
# Epoch 00035: val_loss improved from 0.30085 to 0.29974, saving model to best_model_cnn_emnist.h5
# Epoch 36/5000
# 95879/95879 [==============================] - 18s 188us/step - loss: 0.2894 - acc: 0.8904 - val_loss: 0.3085 - val_acc: 0.8905
#
# Epoch 00036: val_loss did not improve from 0.29974
# Epoch 37/5000
# 95879/95879 [==============================] - 18s 187us/step - loss: 0.2885 - acc: 0.8913 - val_loss: 0.3089 - val_acc: 0.8892
#
# Epoch 00037: val_loss did not improve from 0.29974
# Epoch 38/5000
# 95879/95879 [==============================] - 18s 188us/step - loss: 0.2875 - acc: 0.8914 - val_loss: 0.3006 - val_acc: 0.8923
#
# Epoch 00038: val_loss did not improve from 0.29974
# Epoch 39/5000
# 95879/95879 [==============================] - 18s 187us/step - loss: 0.2836 - acc: 0.8915 - val_loss: 0.3001 - val_acc: 0.8943
#
# Epoch 00039: val_loss did not improve from 0.29974
# Epoch 40/5000
# 95879/95879 [==============================] - 17s 181us/step - loss: 0.2840 - acc: 0.8930 - val_loss: 0.3048 - val_acc: 0.8907
#
# Epoch 00040: val_loss did not improve from 0.29974
# Epoch 41/5000
# 95879/95879 [==============================] - 18s 186us/step - loss: 0.2795 - acc: 0.8930 - val_loss: 0.3037 - val_acc: 0.8916
#
# Epoch 00041: val_loss did not improve from 0.29974
# Epoch 42/5000
# 95879/95879 [==============================] - 18s 190us/step - loss: 0.2790 - acc: 0.8945 - val_loss: 0.2983 - val_acc: 0.8908
#
# Epoch 00042: val_loss improved from 0.29974 to 0.29829, saving model to best_model_cnn_emnist.h5
# Epoch 43/5000
# 95879/95879 [==============================] - 18s 190us/step - loss: 0.2764 - acc: 0.8943 - val_loss: 0.3058 - val_acc: 0.8927
#
# Epoch 00043: val_loss did not improve from 0.29829
# Epoch 44/5000
# 95879/95879 [==============================] - 18s 186us/step - loss: 0.2760 - acc: 0.8938 - val_loss: 0.3043 - val_acc: 0.8933
#
# Epoch 00044: val_loss did not improve from 0.29829
# Epoch 45/5000
# 95879/95879 [==============================] - 18s 186us/step - loss: 0.2746 - acc: 0.8952 - val_loss: 0.3067 - val_acc: 0.8907
#
# Epoch 00045: val_loss did not improve from 0.29829
# Epoch 46/5000
# 95879/95879 [==============================] - 18s 185us/step - loss: 0.2707 - acc: 0.8966 - val_loss: 0.3010 - val_acc: 0.8932
#
# Epoch 00046: val_loss did not improve from 0.29829
# Epoch 47/5000
# 95879/95879 [==============================] - 18s 187us/step - loss: 0.2724 - acc: 0.8957 - val_loss: 0.3037 - val_acc: 0.8905
#
# Epoch 00047: val_loss did not improve from 0.29829
# Epoch 48/5000
# 95879/95879 [==============================] - 18s 189us/step - loss: 0.2678 - acc: 0.8974 - val_loss: 0.3048 - val_acc: 0.8909
#
# Epoch 00048: val_loss did not improve from 0.29829
# Epoch 49/5000
# 95879/95879 [==============================] - 18s 186us/step - loss: 0.2698 - acc: 0.8961 - val_loss: 0.3082 - val_acc: 0.8908
#
# Epoch 00049: val_loss did not improve from 0.29829
# Epoch 50/5000
# 95879/95879 [==============================] - 18s 185us/step - loss: 0.2695 - acc: 0.8965 - val_loss: 0.3007 - val_acc: 0.8941
#
# Epoch 00050: val_loss did not improve from 0.29829
# Epoch 51/5000
# 95879/95879 [==============================] - 18s 186us/step - loss: 0.2652 - acc: 0.8984 - val_loss: 0.3035 - val_acc: 0.8930
#
# Epoch 00051: val_loss did not improve from 0.29829
# Epoch 52/5000
# 95879/95879 [==============================] - 18s 185us/step - loss: 0.2653 - acc: 0.8972 - val_loss: 0.3021 - val_acc: 0.8937
#
# Epoch 00052: val_loss did not improve from 0.29829
# Epoch 53/5000
# 95879/95879 [==============================] - 18s 184us/step - loss: 0.2634 - acc: 0.8982 - val_loss: 0.3061 - val_acc: 0.8930
#
# Epoch 00053: val_loss did not improve from 0.29829
# Epoch 54/5000
# 95879/95879 [==============================] - 17s 181us/step - loss: 0.2637 - acc: 0.8982 - val_loss: 0.3046 - val_acc: 0.8927
#
# Epoch 00054: val_loss did not improve from 0.29829
# Epoch 55/5000
# 95879/95879 [==============================] - 17s 181us/step - loss: 0.2628 - acc: 0.8992 - val_loss: 0.3043 - val_acc: 0.8923
#
# Epoch 00055: val_loss did not improve from 0.29829
# Epoch 56/5000
# 95879/95879 [==============================] - 17s 180us/step - loss: 0.2610 - acc: 0.8994 - val_loss: 0.3000 - val_acc: 0.8935
#
# Epoch 00056: val_loss did not improve from 0.29829
# Epoch 57/5000
# 95879/95879 [==============================] - 17s 180us/step - loss: 0.2600 - acc: 0.9000 - val_loss: 0.3015 - val_acc: 0.8949
#
# Epoch 00057: val_loss did not improve from 0.29829
# Epoch 58/5000
# 95879/95879 [==============================] - 17s 181us/step - loss: 0.2586 - acc: 0.9004 - val_loss: 0.3069 - val_acc: 0.8939
#
# Epoch 00058: val_loss did not improve from 0.29829
# Epoch 59/5000
# 95879/95879 [==============================] - 17s 180us/step - loss: 0.2573 - acc: 0.8994 - val_loss: 0.3055 - val_acc: 0.8941
#
# Epoch 00059: val_loss did not improve from 0.29829
# Epoch 60/5000
# 95879/95879 [==============================] - 17s 180us/step - loss: 0.2574 - acc: 0.8997 - val_loss: 0.3076 - val_acc: 0.8918
#
# Epoch 00060: val_loss did not improve from 0.29829
# Epoch 61/5000
# 95879/95879 [==============================] - 17s 180us/step - loss: 0.2555 - acc: 0.9008 - val_loss: 0.3128 - val_acc: 0.8931
#
# Epoch 00061: val_loss did not improve from 0.29829
# Epoch 62/5000
# 95879/95879 [==============================] - 17s 180us/step - loss: 0.2549 - acc: 0.9004 - val_loss: 0.3077 - val_acc: 0.8918
#
# Epoch 00062: val_loss did not improve from 0.29829
# Epoch 63/5000
# 95879/95879 [==============================] - 17s 181us/step - loss: 0.2532 - acc: 0.9013 - val_loss: 0.3052 - val_acc: 0.8940
#
# Epoch 00063: val_loss did not improve from 0.29829
# Epoch 64/5000
# 95879/95879 [==============================] - 17s 180us/step - loss: 0.2537 - acc: 0.9015 - val_loss: 0.3107 - val_acc: 0.8896
#
# Epoch 00064: val_loss did not improve from 0.29829
# Epoch 65/5000
# 95879/95879 [==============================] - 17s 180us/step - loss: 0.2535 - acc: 0.9020 - val_loss: 0.3113 - val_acc: 0.8918
#
# Epoch 00065: val_loss did not improve from 0.29829
# Epoch 66/5000
# 95879/95879 [==============================] - 17s 180us/step - loss: 0.2515 - acc: 0.9025 - val_loss: 0.3071 - val_acc: 0.8935
#
# Epoch 00066: val_loss did not improve from 0.29829
# Epoch 67/5000
# 95879/95879 [==============================] - 17s 180us/step - loss: 0.2485 - acc: 0.9026 - val_loss: 0.3067 - val_acc: 0.8933
#
# Epoch 00067: val_loss did not improve from 0.29829
# Epoch 00067: early stopping

# %%
# Function definition for plot accuracy
acc = model_history.history['acc']
val_acc = model_history.history['val_acc']
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']
epochs = range(1,len(acc)+1)

# %%
# Function definition for plot accuracy
def plotgraph_a(epochs, acc, val_acc):
    # Plot training & validation accuracy values
    plt.plot(epochs, acc, 'b')
    plt.plot(epochs, val_acc, 'g')
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Training', 'Validation'], loc = 'lower right')
    plt.show()

# Accuracy curve
plotgraph_a(epochs, acc, val_acc)

# %%
# Function definition for plot loss
def plotgraph_l(epochs, loss, val_loss):
    # Plot training & validation loss values
    plt.plot(epochs, loss, 'b')
    plt.plot(epochs, val_loss, 'g')
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Training', 'Validation'], loc = 'upper right')
    plt.show()

# Loss curve
plotgraph_l(epochs, loss, val_loss)

# %%
# Evaluate model
scores = model.evaluate(test_x, test_y, verbose=0)
print(f'Score: {model.metrics_names[0]} of {round(scores[0], 4)}; '
      f'{model.metrics_names[1]} of {round((scores[1]*100), 4)}%')
# Out:
# Score: loss of 0.3203; acc of 89.1909%

# %%
y_pred = model.predict(test_x)
y_pred = (y_pred > 0.5)

# %%
# Confusion matrix (scikit-learn)
cm = metrics.confusion_matrix(test_y.argmax(axis=1), y_pred.argmax(axis=1))

# %%
# Create Seaborn Heatmap for Confusion Matrix
import seaborn as sn

# Get labels from mapp series and convert to a string
labels = np.array(mapp.values, dtype=np.uint8).view('S1')
labels = labels.astype(str)
labels = pd.Series(labels)
map_labels = labels.values.tolist()

df_cm = pd.DataFrame(cm, index=labels, columns=labels)
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
plt.figure(figsize = (24,17))
sn.set(font_scale=1.5) # for label size
ax = sn.heatmap(df_cm, cmap="YlGnBu", annot=True, annot_kws={"size": 12}, fmt='g') # font size
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
ax.set_xticklabels = map_labels
ax.set_yticklabels = map_labels
plt.show()

# Used to fix matplotlib v.3.1.1 error that cutoff top and bottom of heatmap
# ax = sn.heatmap(df_corr, annot=True) #notation: "annot" not "annote"
# bottom, top = ax.get_ylim()
# ax.set_ylim(bottom + 0.5, top - 0.5)

# %%
# Load the saved model
saved_model = load_model(FILE_PATH)

# Evaluate the saved model
scores = saved_model.evaluate(test_x, test_y, verbose = 1)
print(f'Score: {saved_model.metrics_names[0]} of {round(scores[0], 4)}; '
      f'{saved_model.metrics_names[1]} of {round((scores[1]*100), 4)}%')
# Out:
# 18799/18799 [==============================] - 2s 84us/step
# Score: loss of 0.3091; acc of 88.9994%
