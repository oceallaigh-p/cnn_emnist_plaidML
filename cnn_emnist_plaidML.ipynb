# %%
# Add GPU support through PlaidML
import os
os.environ["KERAS_BACKEND"] = "plaidml.keras.backend"

import keras
# Out:
# Using plaidml.keras.backend backend.

# %%
# Import modules
from keras import layers
from keras import models
from keras import utils
from keras import callbacks

from keras.models import load_model

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics

# %%
## Constants

# Image Dimensions (pixels)
HEIGHT = 28
WIDTH = 28

# Train test split
TEST_SIZE = 0.15   # 85 / 15 split

# Random seed
SEED = 42

# Batch size and number of training epochs
BATCH_SIZE = 256
EPOCHS = 5000

# Early stop parameters
PATIENCE = 25                          # Number of epochs without improvement
MIN_DELTA = 0.0001                     # Minimum change to be considered improvement
MONITOR = 'val_loss'                   # Variable being monitored
MODE = 'min'                           # Mode for monitor (minimize validation loss)
FILE_PATH = 'best_model_cnn_emnist.h5' # Path to saved model

# %%
# Fix numpy random seed
np.random.seed(SEED)

# %%
# Load data
train = pd.read_csv("/Users/patrickoceallaigh/Data/EMNIST/kaggle_csv/emnist-balanced-train.csv",delimiter = ',')
test = pd.read_csv("/Users/patrickoceallaigh/Data/EMNIST/kaggle_csv/emnist-balanced-test.csv", delimiter = ',')
mapp = pd.read_csv("/Users/patrickoceallaigh/Data/EMNIST/kaggle_csv/emnist-balanced-mapping.txt", delimiter = ' ',
                   index_col = 0, header = None, squeeze = True)

print("Train: %s, Test: %s, Map: %s" %(train.shape, test.shape, mapp.shape))
# Out:
# Train: (112799, 785), Test: (18799, 785), Map: (47,)

# %%
# Split x and y
train_x = train.iloc[:,1:]
train_y = train.iloc[:,0]
del train

test_x = test.iloc[:,1:]
test_y = test.iloc[:,0]
del test

print(train_x.shape,train_y.shape,test_x.shape,test_y.shape)
# Out:
# (112799, 784) (112799,) (18799, 784) (18799,)

# %%
# Define function to flip and rotate image
def rotate(image):
    image = image.reshape([HEIGHT, WIDTH])
    image = np.fliplr(image)
    image = np.rot90(image)
    return image

# %%
# Flip and rotate image
train_x = np.asarray(train_x)
train_x = np.apply_along_axis(rotate, 1, train_x)
print ("train_x:",train_x.shape)

test_x = np.asarray(test_x)
test_x = np.apply_along_axis(rotate, 1, test_x)
print ("test_x:",test_x.shape)
# Out:
# train_x: (112799, 28, 28)
# test_x: (18799, 28, 28)

# %%
# Normalise
train_x = train_x.astype('float32')
train_x /= 255
test_x = test_x.astype('float32')
test_x /= 255

# %%
# Plot images
for i in range(100, 109):
    plt.subplot(330 + (i+1))
    plt.imshow(train_x[i], cmap = plt.get_cmap('gray'))
    plt.title(chr(mapp[train_y[i]]))

# %%
# Number of classes
num_classes = train_y.nunique()
print ("Number of Classes:", num_classes)
# Out:
# Number of Classes: 47

# %%
# One hot encoding
train_y = utils.np_utils.to_categorical(train_y, num_classes)
test_y = utils.np_utils.to_categorical(test_y, num_classes)
print("train_y: ", train_y.shape)
print("test_y: ", test_y.shape)
# Out:
# train_y:  (112799, 47)
# test_y:  (18799, 47)

# %%
# Reshape image for CNN
train_x = train_x.reshape(-1, HEIGHT, WIDTH, 1)
test_x = test_x.reshape(-1, HEIGHT, WIDTH, 1)

# %%
# Partition to train and val
train_x, val_x, train_y, val_y = train_test_split(train_x, train_y, test_size = TEST_SIZE, random_state = SEED)

# %%
# Build model
model = models.Sequential()

model.add(layers.Conv2D(filters = 32,
                        kernel_size = (3,3),
                        padding = 'same',
                        activation = 'relu',
                        input_shape = (HEIGHT, WIDTH,1)))
model.add(layers.MaxPooling2D(pool_size = (2,2)))
model.add(layers.Conv2D(filters = 64,
                        kernel_size = (3,3),
                        padding = 'same',
                        activation = 'relu'))
model.add(layers.MaxPooling2D(pool_size = (2,2)))
model.add(layers.Conv2D(filters = 64,
                        kernel_size = (3,3),
                        padding = 'same',
                        activation = 'relu'))
model.add(layers.MaxPooling2D(pool_size=(2,2)))
model.add(layers.Flatten())
model.add(layers.Dropout(.5))
model.add(layers.Dense(units = 64,
                       activation = 'relu'))
model.add(layers.Dense(units = num_classes,
                       activation = 'softmax'))

model.summary()
# Out:
# INFO:plaidml:Opening device "metal_amd_radeon_pro_vega_56.0"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 28, 28, 32)        320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 64)          36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 576)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                36928
# _________________________________________________________________
# dense_2 (Dense)              (None, 47)                3055
# =================================================================
# Total params: 95,727
# Trainable params: 95,727
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile model
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
# Set callback functions to stop training early and save the best model so far
keras_callbacks   = [
    callbacks.EarlyStopping(monitor = MONITOR, patience = PATIENCE, mode = MODE, min_delta = MIN_DELTA, verbose = 1),
    callbacks.ModelCheckpoint(filepath = FILE_PATH, monitor = MONITOR, save_best_only = True, mode = MODE, verbose = 1)
]

# %%
# Fit model
model_history = model.fit(train_x, train_y,
                    epochs = EPOCHS,
                    batch_size = BATCH_SIZE,
                    verbose = 1,
                    validation_data=(val_x, val_y), 
                    callbacks = keras_callbacks)
# Out:
# Train on 95879 samples, validate on 16920 samples
# Epoch 1/5000
# 95879/95879 [==============================] - 23s 236us/step - loss: 1.4089 - acc: 0.5895 - val_loss: 0.5444 - val_acc: 0.8189
#
# Epoch 00001: val_loss improved from inf to 0.54439, saving model to best_model_cnn_emnist.h5
# Epoch 2/5000
# 95879/95879 [==============================] - 17s 177us/step - loss: 0.6391 - acc: 0.7901 - val_loss: 0.4374 - val_acc: 0.8463
#
# Epoch 00002: val_loss improved from 0.54439 to 0.43736, saving model to best_model_cnn_emnist.h5
# Epoch 3/5000
# 95879/95879 [==============================] - 17s 177us/step - loss: 0.5437 - acc: 0.8194 - val_loss: 0.3969 - val_acc: 0.8581
#
# Epoch 00003: val_loss improved from 0.43736 to 0.39695, saving model to best_model_cnn_emnist.h5
# Epoch 4/5000
# 95879/95879 [==============================] - 17s 178us/step - loss: 0.4955 - acc: 0.8323 - val_loss: 0.3776 - val_acc: 0.8646
#
# Epoch 00004: val_loss improved from 0.39695 to 0.37761, saving model to best_model_cnn_emnist.h5
# Epoch 5/5000
# 95879/95879 [==============================] - 17s 178us/step - loss: 0.4657 - acc: 0.8412 - val_loss: 0.3586 - val_acc: 0.8675
#
# Epoch 00005: val_loss improved from 0.37761 to 0.35856, saving model to best_model_cnn_emnist.h5
# Epoch 6/5000
# 95879/95879 [==============================] - 17s 179us/step - loss: 0.4464 - acc: 0.8456 - val_loss: 0.3448 - val_acc: 0.8732
#
# Epoch 00006: val_loss improved from 0.35856 to 0.34478, saving model to best_model_cnn_emnist.h5
# Epoch 7/5000
# 95879/95879 [==============================] - 17s 178us/step - loss: 0.4285 - acc: 0.8516 - val_loss: 0.3408 - val_acc: 0.8736
#
# Epoch 00007: val_loss improved from 0.34478 to 0.34078, saving model to best_model_cnn_emnist.h5
# Epoch 8/5000
# 95879/95879 [==============================] - 17s 178us/step - loss: 0.4125 - acc: 0.8558 - val_loss: 0.3397 - val_acc: 0.8749
#
# Epoch 00008: val_loss improved from 0.34078 to 0.33968, saving model to best_model_cnn_emnist.h5
# Epoch 9/5000
# 95879/95879 [==============================] - 17s 179us/step - loss: 0.4032 - acc: 0.8581 - val_loss: 0.3388 - val_acc: 0.8736
#
# Epoch 00009: val_loss improved from 0.33968 to 0.33882, saving model to best_model_cnn_emnist.h5
# Epoch 10/5000
# 95879/95879 [==============================] - 17s 179us/step - loss: 0.3901 - acc: 0.8626 - val_loss: 0.3260 - val_acc: 0.8789
#
# Epoch 00010: val_loss improved from 0.33882 to 0.32596, saving model to best_model_cnn_emnist.h5
# Epoch 11/5000
# 95879/95879 [==============================] - 17s 179us/step - loss: 0.3847 - acc: 0.8643 - val_loss: 0.3244 - val_acc: 0.8805
#
# Epoch 00011: val_loss improved from 0.32596 to 0.32437, saving model to best_model_cnn_emnist.h5
# Epoch 12/5000
# 95879/95879 [==============================] - 17s 180us/step - loss: 0.3766 - acc: 0.8674 - val_loss: 0.3209 - val_acc: 0.8800
#
# Epoch 00012: val_loss improved from 0.32437 to 0.32094, saving model to best_model_cnn_emnist.h5
# Epoch 13/5000
# 95879/95879 [==============================] - 17s 179us/step - loss: 0.3704 - acc: 0.8681 - val_loss: 0.3160 - val_acc: 0.8824
#
# Epoch 00013: val_loss improved from 0.32094 to 0.31600, saving model to best_model_cnn_emnist.h5
# Epoch 14/5000
# 95879/95879 [==============================] - 17s 179us/step - loss: 0.3616 - acc: 0.8710 - val_loss: 0.3121 - val_acc: 0.8849
#
# Epoch 00014: val_loss improved from 0.31600 to 0.31212, saving model to best_model_cnn_emnist.h5
# Epoch 15/5000
# 95879/95879 [==============================] - 17s 179us/step - loss: 0.3582 - acc: 0.8709 - val_loss: 0.3096 - val_acc: 0.8865
#
# Epoch 00015: val_loss improved from 0.31212 to 0.30963, saving model to best_model_cnn_emnist.h5
# Epoch 16/5000
# 95879/95879 [==============================] - 17s 179us/step - loss: 0.3510 - acc: 0.8720 - val_loss: 0.3073 - val_acc: 0.8846
#
# Epoch 00016: val_loss improved from 0.30963 to 0.30725, saving model to best_model_cnn_emnist.h5
# Epoch 17/5000
# 95879/95879 [==============================] - 17s 179us/step - loss: 0.3468 - acc: 0.8758 - val_loss: 0.3026 - val_acc: 0.8874
#
# Epoch 00017: val_loss improved from 0.30725 to 0.30262, saving model to best_model_cnn_emnist.h5
# Epoch 18/5000
# 95879/95879 [==============================] - 17s 179us/step - loss: 0.3412 - acc: 0.8754 - val_loss: 0.2964 - val_acc: 0.8879
#
# Epoch 00018: val_loss improved from 0.30262 to 0.29640, saving model to best_model_cnn_emnist.h5
# Epoch 19/5000
# 95879/95879 [==============================] - 17s 179us/step - loss: 0.3382 - acc: 0.8775 - val_loss: 0.3040 - val_acc: 0.8842
#
# Epoch 00019: val_loss did not improve from 0.29640
# Epoch 20/5000
# 95879/95879 [==============================] - 17s 179us/step - loss: 0.3328 - acc: 0.8790 - val_loss: 0.3011 - val_acc: 0.8875
#
# Epoch 00020: val_loss did not improve from 0.29640
# Epoch 21/5000
# 95879/95879 [==============================] - 17s 178us/step - loss: 0.3287 - acc: 0.8798 - val_loss: 0.2991 - val_acc: 0.8866
#
# Epoch 00021: val_loss did not improve from 0.29640
# Epoch 22/5000
# 95879/95879 [==============================] - 17s 179us/step - loss: 0.3258 - acc: 0.8820 - val_loss: 0.3001 - val_acc: 0.8882
#
# Epoch 00022: val_loss did not improve from 0.29640
# Epoch 23/5000
# 95879/95879 [==============================] - 17s 179us/step - loss: 0.3222 - acc: 0.8822 - val_loss: 0.2951 - val_acc: 0.8884
#
# Epoch 00023: val_loss improved from 0.29640 to 0.29512, saving model to best_model_cnn_emnist.h5
# Epoch 24/5000
# 95879/95879 [==============================] - 17s 179us/step - loss: 0.3203 - acc: 0.8830 - val_loss: 0.2990 - val_acc: 0.8879
#
# Epoch 00024: val_loss did not improve from 0.29512
# Epoch 25/5000
# 95879/95879 [==============================] - 17s 180us/step - loss: 0.3152 - acc: 0.8840 - val_loss: 0.2972 - val_acc: 0.8873
#
# Epoch 00025: val_loss did not improve from 0.29512
# Epoch 26/5000
# 95879/95879 [==============================] - 17s 180us/step - loss: 0.3148 - acc: 0.8843 - val_loss: 0.2949 - val_acc: 0.8888
#
# Epoch 00026: val_loss improved from 0.29512 to 0.29485, saving model to best_model_cnn_emnist.h5
# Epoch 27/5000
# 95879/95879 [==============================] - 17s 180us/step - loss: 0.3113 - acc: 0.8847 - val_loss: 0.3025 - val_acc: 0.8859
#
# Epoch 00027: val_loss did not improve from 0.29485
# Epoch 28/5000
# 95879/95879 [==============================] - 17s 180us/step - loss: 0.3089 - acc: 0.8858 - val_loss: 0.2944 - val_acc: 0.8899
#
# Epoch 00028: val_loss improved from 0.29485 to 0.29439, saving model to best_model_cnn_emnist.h5
# Epoch 29/5000
# 95879/95879 [==============================] - 18s 184us/step - loss: 0.3052 - acc: 0.8865 - val_loss: 0.2897 - val_acc: 0.8903
#
# Epoch 00029: val_loss improved from 0.29439 to 0.28966, saving model to best_model_cnn_emnist.h5
# Epoch 30/5000
# 95879/95879 [==============================] - 18s 188us/step - loss: 0.3022 - acc: 0.8874 - val_loss: 0.2975 - val_acc: 0.8878
#
# Epoch 00030: val_loss did not improve from 0.28966
# Epoch 31/5000
# 95879/95879 [==============================] - 18s 186us/step - loss: 0.3019 - acc: 0.8876 - val_loss: 0.2958 - val_acc: 0.8905
#
# Epoch 00031: val_loss did not improve from 0.28966
# Epoch 32/5000
# 95879/95879 [==============================] - 18s 188us/step - loss: 0.2994 - acc: 0.8886 - val_loss: 0.2993 - val_acc: 0.8882
#
# Epoch 00032: val_loss did not improve from 0.28966
# Epoch 33/5000
# 95879/95879 [==============================] - 18s 191us/step - loss: 0.2975 - acc: 0.8887 - val_loss: 0.2931 - val_acc: 0.8891
#
# Epoch 00033: val_loss did not improve from 0.28966
# Epoch 34/5000
# 95879/95879 [==============================] - 18s 193us/step - loss: 0.2939 - acc: 0.8895 - val_loss: 0.2909 - val_acc: 0.8914
#
# Epoch 00034: val_loss did not improve from 0.28966
# Epoch 35/5000
# 95879/95879 [==============================] - 18s 188us/step - loss: 0.2931 - acc: 0.8902 - val_loss: 0.2917 - val_acc: 0.8915
#
# Epoch 00035: val_loss did not improve from 0.28966
# Epoch 36/5000
# 95879/95879 [==============================] - 18s 188us/step - loss: 0.2901 - acc: 0.8905 - val_loss: 0.2932 - val_acc: 0.8912
#
# Epoch 00036: val_loss did not improve from 0.28966
# Epoch 37/5000
# 95879/95879 [==============================] - 18s 190us/step - loss: 0.2888 - acc: 0.8926 - val_loss: 0.2901 - val_acc: 0.8901
#
# Epoch 00037: val_loss did not improve from 0.28966
# Epoch 38/5000
# 95879/95879 [==============================] - 18s 187us/step - loss: 0.2860 - acc: 0.8919 - val_loss: 0.2920 - val_acc: 0.8902
#
# Epoch 00038: val_loss did not improve from 0.28966
# Epoch 39/5000
# 95879/95879 [==============================] - 18s 186us/step - loss: 0.2854 - acc: 0.8919 - val_loss: 0.2944 - val_acc: 0.8917
#
# Epoch 00039: val_loss did not improve from 0.28966
# Epoch 40/5000
# 95879/95879 [==============================] - 18s 184us/step - loss: 0.2816 - acc: 0.8934 - val_loss: 0.2917 - val_acc: 0.8917
#
# Epoch 00040: val_loss did not improve from 0.28966
# Epoch 41/5000
# 95879/95879 [==============================] - 17s 180us/step - loss: 0.2801 - acc: 0.8935 - val_loss: 0.2939 - val_acc: 0.8901
#
# Epoch 00041: val_loss did not improve from 0.28966
# Epoch 42/5000
# 95879/95879 [==============================] - 17s 181us/step - loss: 0.2794 - acc: 0.8942 - val_loss: 0.2958 - val_acc: 0.8920
#
# Epoch 00042: val_loss did not improve from 0.28966
# Epoch 43/5000
# 95879/95879 [==============================] - 18s 184us/step - loss: 0.2786 - acc: 0.8938 - val_loss: 0.2954 - val_acc: 0.8917
#
# Epoch 00043: val_loss did not improve from 0.28966
# Epoch 44/5000
# 95879/95879 [==============================] - 18s 186us/step - loss: 0.2783 - acc: 0.8942 - val_loss: 0.2920 - val_acc: 0.8921
#
# Epoch 00044: val_loss did not improve from 0.28966
# Epoch 45/5000
# 95879/95879 [==============================] - 18s 187us/step - loss: 0.2714 - acc: 0.8964 - val_loss: 0.2948 - val_acc: 0.8914
#
# Epoch 00045: val_loss did not improve from 0.28966
# Epoch 46/5000
# 95879/95879 [==============================] - 18s 184us/step - loss: 0.2728 - acc: 0.8954 - val_loss: 0.2916 - val_acc: 0.8944
#
# Epoch 00046: val_loss did not improve from 0.28966
# Epoch 47/5000
# 95879/95879 [==============================] - 17s 181us/step - loss: 0.2728 - acc: 0.8956 - val_loss: 0.2915 - val_acc: 0.8930
#
# Epoch 00047: val_loss did not improve from 0.28966
# Epoch 48/5000
# 95879/95879 [==============================] - 17s 182us/step - loss: 0.2712 - acc: 0.8955 - val_loss: 0.2924 - val_acc: 0.8919
#
# Epoch 00048: val_loss did not improve from 0.28966
# Epoch 49/5000
# 95879/95879 [==============================] - 17s 181us/step - loss: 0.2669 - acc: 0.8973 - val_loss: 0.2919 - val_acc: 0.8949
#
# Epoch 00049: val_loss did not improve from 0.28966
# Epoch 50/5000
# 95879/95879 [==============================] - 17s 181us/step - loss: 0.2681 - acc: 0.8963 - val_loss: 0.2929 - val_acc: 0.8932
#
# Epoch 00050: val_loss did not improve from 0.28966
# Epoch 51/5000
# 95879/95879 [==============================] - 17s 182us/step - loss: 0.2655 - acc: 0.8970 - val_loss: 0.2945 - val_acc: 0.8939
#
# Epoch 00051: val_loss did not improve from 0.28966
# Epoch 52/5000
# 95879/95879 [==============================] - 17s 182us/step - loss: 0.2637 - acc: 0.8982 - val_loss: 0.2960 - val_acc: 0.8926
#
# Epoch 00052: val_loss did not improve from 0.28966
# Epoch 53/5000
# 95879/95879 [==============================] - 17s 181us/step - loss: 0.2631 - acc: 0.8990 - val_loss: 0.2929 - val_acc: 0.8916
#
# Epoch 00053: val_loss did not improve from 0.28966
# Epoch 54/5000
# 95879/95879 [==============================] - 17s 182us/step - loss: 0.2635 - acc: 0.8978 - val_loss: 0.2857 - val_acc: 0.8922
#
# Epoch 00054: val_loss improved from 0.28966 to 0.28574, saving model to best_model_cnn_emnist.h5
# Epoch 55/5000
# 95879/95879 [==============================] - 17s 181us/step - loss: 0.2605 - acc: 0.8996 - val_loss: 0.2965 - val_acc: 0.8926
#
# Epoch 00055: val_loss did not improve from 0.28574
# Epoch 56/5000
# 95879/95879 [==============================] - 17s 180us/step - loss: 0.2600 - acc: 0.8995 - val_loss: 0.2940 - val_acc: 0.8929
#
# Epoch 00056: val_loss did not improve from 0.28574
# Epoch 57/5000
# 95879/95879 [==============================] - 17s 180us/step - loss: 0.2580 - acc: 0.9001 - val_loss: 0.2972 - val_acc: 0.8921
#
# Epoch 00057: val_loss did not improve from 0.28574
# Epoch 58/5000
# 95879/95879 [==============================] - 17s 180us/step - loss: 0.2581 - acc: 0.8998 - val_loss: 0.2929 - val_acc: 0.8933
#
# Epoch 00058: val_loss did not improve from 0.28574
# Epoch 59/5000
# 95879/95879 [==============================] - 17s 180us/step - loss: 0.2573 - acc: 0.8998 - val_loss: 0.2951 - val_acc: 0.8935
#
# Epoch 00059: val_loss did not improve from 0.28574
# Epoch 60/5000
# 95879/95879 [==============================] - 17s 180us/step - loss: 0.2583 - acc: 0.8995 - val_loss: 0.2936 - val_acc: 0.8926
#
# Epoch 00060: val_loss did not improve from 0.28574
# Epoch 61/5000
# 95879/95879 [==============================] - 17s 180us/step - loss: 0.2538 - acc: 0.9012 - val_loss: 0.2972 - val_acc: 0.8933
#
# Epoch 00061: val_loss did not improve from 0.28574
# Epoch 62/5000
# 95879/95879 [==============================] - 17s 180us/step - loss: 0.2548 - acc: 0.9009 - val_loss: 0.2997 - val_acc: 0.8901
#
# Epoch 00062: val_loss did not improve from 0.28574
# Epoch 63/5000
# 95879/95879 [==============================] - 17s 179us/step - loss: 0.2541 - acc: 0.9011 - val_loss: 0.2997 - val_acc: 0.8930
#
# Epoch 00063: val_loss did not improve from 0.28574
# Epoch 64/5000
# 95879/95879 [==============================] - 17s 179us/step - loss: 0.2533 - acc: 0.9014 - val_loss: 0.2973 - val_acc: 0.8934
#
# Epoch 00064: val_loss did not improve from 0.28574
# Epoch 65/5000
# 95879/95879 [==============================] - 17s 179us/step - loss: 0.2509 - acc: 0.9034 - val_loss: 0.2982 - val_acc: 0.8934
#
# Epoch 00065: val_loss did not improve from 0.28574
# Epoch 66/5000
# 95879/95879 [==============================] - 17s 179us/step - loss: 0.2477 - acc: 0.9031 - val_loss: 0.2965 - val_acc: 0.8934
#
# Epoch 00066: val_loss did not improve from 0.28574
# Epoch 67/5000
# 95879/95879 [==============================] - 17s 180us/step - loss: 0.2508 - acc: 0.9020 - val_loss: 0.2944 - val_acc: 0.8931
#
# Epoch 00067: val_loss did not improve from 0.28574
# Epoch 68/5000
# 95879/95879 [==============================] - 17s 179us/step - loss: 0.2475 - acc: 0.9037 - val_loss: 0.3001 - val_acc: 0.8916
#
# Epoch 00068: val_loss did not improve from 0.28574
# Epoch 69/5000
# 95879/95879 [==============================] - 17s 179us/step - loss: 0.2470 - acc: 0.9033 - val_loss: 0.2973 - val_acc: 0.8934
#
# Epoch 00069: val_loss did not improve from 0.28574
# Epoch 70/5000
# 95879/95879 [==============================] - 17s 179us/step - loss: 0.2473 - acc: 0.9039 - val_loss: 0.2961 - val_acc: 0.8921
#
# Epoch 00070: val_loss did not improve from 0.28574
# Epoch 71/5000
# 95879/95879 [==============================] - 17s 179us/step - loss: 0.2441 - acc: 0.9037 - val_loss: 0.2988 - val_acc: 0.8902
#
# Epoch 00071: val_loss did not improve from 0.28574
# Epoch 72/5000
# 95879/95879 [==============================] - 17s 179us/step - loss: 0.2449 - acc: 0.9030 - val_loss: 0.3009 - val_acc: 0.8928
#
# Epoch 00072: val_loss did not improve from 0.28574
# Epoch 73/5000
# 95879/95879 [==============================] - 17s 179us/step - loss: 0.2421 - acc: 0.9051 - val_loss: 0.3004 - val_acc: 0.8928
#
# Epoch 00073: val_loss did not improve from 0.28574
# Epoch 74/5000
# 95879/95879 [==============================] - 17s 180us/step - loss: 0.2431 - acc: 0.9040 - val_loss: 0.3041 - val_acc: 0.8927
#
# Epoch 00074: val_loss did not improve from 0.28574
# Epoch 75/5000
# 95879/95879 [==============================] - 17s 180us/step - loss: 0.2397 - acc: 0.9059 - val_loss: 0.3045 - val_acc: 0.8897
#
# Epoch 00075: val_loss did not improve from 0.28574
# Epoch 76/5000
# 95879/95879 [==============================] - 17s 179us/step - loss: 0.2428 - acc: 0.9045 - val_loss: 0.3005 - val_acc: 0.8920
#
# Epoch 00076: val_loss did not improve from 0.28574
# Epoch 77/5000
# 95879/95879 [==============================] - 17s 179us/step - loss: 0.2404 - acc: 0.9058 - val_loss: 0.3056 - val_acc: 0.8925
#
# Epoch 00077: val_loss did not improve from 0.28574
# Epoch 78/5000
# 95879/95879 [==============================] - 17s 179us/step - loss: 0.2391 - acc: 0.9053 - val_loss: 0.3017 - val_acc: 0.8935
#
# Epoch 00078: val_loss did not improve from 0.28574
# Epoch 79/5000
# 95879/95879 [==============================] - 17s 179us/step - loss: 0.2392 - acc: 0.9044 - val_loss: 0.3017 - val_acc: 0.8928
#
# Epoch 00079: val_loss did not improve from 0.28574
# Epoch 00079: early stopping

# %%
# Function definition for plot accuracy
acc = model_history.history['acc']
val_acc = model_history.history['val_acc']
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']
epochs = range(1,len(acc)+1)

# %%
# Function definition for plot accuracy
def plotgraph_a(epochs, acc, val_acc):
    # Plot training & validation accuracy values
    plt.plot(epochs, acc, 'b')
    plt.plot(epochs, val_acc, 'g')
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Training', 'Validation'], loc = 'lower right')
    plt.show()

# Accuracy curve
plotgraph_a(epochs, acc, val_acc)

# %%
# Function definition for plot loss
def plotgraph_l(epochs, loss, val_loss):
    # Plot training & validation loss values
    plt.plot(epochs, loss, 'b')
    plt.plot(epochs, val_loss, 'g')
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Training', 'Validation'], loc = 'upper right')
    plt.show()

# Loss curve
plotgraph_l(epochs, loss, val_loss)

# %%
# Evaluate model
scores = model.evaluate(test_x, test_y, verbose=0)
print(f'Score: {model.metrics_names[0]} of {round(scores[0], 4)}; '
      f'{model.metrics_names[1]} of {round((scores[1]*100), 4)}%')
# Out:
# Score: loss of 0.3228; acc of 89.2973%

# %%
y_pred = model.predict(test_x)
y_pred = (y_pred > 0.5)

# %%
# Confusion matrix (scikit-learn)
cm = metrics.confusion_matrix(test_y.argmax(axis=1), y_pred.argmax(axis=1))

# %%
# Create Seaborn Heatmap for Confusion Matrix
import seaborn as sn

# Get labels from mapp series and convert to a string
labels = np.array(mapp.values, dtype=np.uint8).view('S1')
labels = labels.astype(str)
labels = pd.Series(labels)
map_labels = labels.values.tolist()

df_cm = pd.DataFrame(cm, index=labels, columns=labels)
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
plt.figure(figsize = (24,17))
sn.set(font_scale=1.5) # for label size
ax = sn.heatmap(df_cm, cmap="YlGnBu", annot=True, annot_kws={"size": 12}, fmt='g') # font size
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
ax.set_xticklabels = map_labels
ax.set_yticklabels = map_labels
plt.show()

# Used to fix matplotlib v.3.1.1 error that cutoff top and bottom of heatmap
# ax = sn.heatmap(df_corr, annot=True) #notation: "annot" not "annote"
# bottom, top = ax.get_ylim()
# ax.set_ylim(bottom + 0.5, top - 0.5)

# %%
# Load the saved model
saved_model = load_model(FILE_PATH)

# Evaluate the saved model
scores = saved_model.evaluate(test_x, test_y, verbose = 1)
print(f'Score: {saved_model.metrics_names[0]} of {round(scores[0], 4)}; '
      f'{saved_model.metrics_names[1]} of {round((scores[1]*100), 4)}%')
# Out:
# 18799/18799 [==============================] - 2s 84us/step
# Score: loss of 0.308; acc of 89.2707%
